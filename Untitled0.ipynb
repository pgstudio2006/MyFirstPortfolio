# %% [markdown]
# <a href="https://colab.research.google.com/github/pgstudio2006/MyFirstPortfolio/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
salary=[40000,45000,48500,42500]
cgpa=[8,8.5,9,7]
plt.plot(salary,cgpa)
plt.title("salary vs cgpa")
plt.xlabel("salary")
plt.ylabel("cgpa")
plt.show()
